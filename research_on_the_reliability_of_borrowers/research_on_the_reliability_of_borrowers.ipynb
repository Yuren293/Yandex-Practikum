# %% [markdown]
# ## Исследование надёжности заёмщиков

# %% [markdown]
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели кредитного скоринга — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.

# %% [markdown]
# ### План выполнения работы
# Шаг 1. Открыть таблицу и изучить общую информацию о данных
#
# Шаг 2. Предобработка данных
#
# Шаг 3. Предоставление ответов на вопросы :
# Есть ли зависимость между наличием детей и возвратом кредита в срок?
# Есть ли зависимость между семейным положением и возвратом кредита в срок?
# Есть ли зависимость между уровнем дохода и возвратом кредита в срок?
# Как разные цели кредита влияют на его возврат в срок?
#
# Шаг 4. Написание общего вывода

# %% [markdown]
# ### Описание данных
# 1. children — количество детей в семье
# 2. days_employed — общий трудовой стаж в днях
# 3. dob_years — возраст клиента в годах
# 4. education — уровень образования клиента
# 5. education_id — идентификатор уровня образования
# 6. family_status — семейное положение
# 7. family_status_id — идентификатор семейного положения
# 8. gender — пол клиента
# 9. income_type — тип занятости
# 10. debt — имел ли задолженность по возврату кредитов
# 11. total_income — ежемесячный доход
# 12. purpose — цель получения кредита

# %% [markdown]
# ### Шаг 1. Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd  # вставил импорт в отдельную ячейку, как ты порекомендовал

# %%
client_data = pd.read_csv('/datasets/data.csv')
client_data.info()  # посмотрим типы значений в столбцах таблиц и их значения
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       19351 non-null float64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        19351 non-null float64
# purpose             21525 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %%
client_data.head(10) # посмотрим структуру таблицы
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.673028         42    высшее             0
# 1         1   -4024.803754         36   среднее             1
# 2         0   -5623.422610         33   Среднее             1
# 3         3   -4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
# 5         0    -926.185831         27    высшее             0
# 6         0   -2879.202052         43    высшее             0
# 7         0    -152.779569         50   СРЕДНЕЕ             1
# 8         2   -6929.865299         35    ВЫСШЕЕ             0
# 9         0   -2188.756445         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
# 5  гражданский брак                 1      M   компаньон     0  255763.565419
# 6   женат / замужем                 0      F   компаньон     0  240525.971920
# 7   женат / замужем                 0      M   сотрудник     0  135823.934197
# 8  гражданский брак                 1      F   сотрудник     0   95856.832424
# 9   женат / замужем                 0      M   сотрудник     0  144425.938277
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу
# 5               покупка жилья
# 6           операции с жильем
# 7                 образование
# 8       на проведение свадьбы
# 9     покупка жилья для семьи

# %%
#получив название всех столбцов, узнаю в них количество различных значений:

columns_names = ['children', 'days_employed', 'dob_years', 'education', 'education_id', 'family_status', 'family_status_id', 'gender', 'income_type', 'debt', 'total_income', 'purpose']
for name in columns_names:
    print(client_data[name].value_counts())
# Out:
#  0     14149
#  1      4818
#  2      2055
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: children, dtype: int64
# -986.927316       1
# -7026.359174      1
# -4236.274243      1
# -6620.396473      1
# -1238.560080      1
# -3047.519891      1
# -7373.150635      1
# -1048.380461      1
# -4906.125062      1
# -1893.222792      1
# -849.764227       1
# -1741.489608      1
# -5135.928528      1
# -1453.358707      1
# -4977.646061      1
#  396078.542064    1
# -1399.361282      1
# -1645.463049      1
#  386155.404320    1
# -2793.736218      1
# -1171.322169      1
# -158.140270       1
# -978.830019       1
# -941.943913       1
# -5208.815041      1
# -951.868467       1
# -501.078443       1
# -725.971741       1
# -2308.532389      1
# -666.570650       1
#                  ..
# -1478.092467      1
# -568.348795       1
# -3453.437905      1
# -725.595743       1
# -2013.336934      1
# -215.245268       1
# -3208.792519      1
# -1799.455775      1
# -979.587235       1
# -1312.334477      1
# -2184.000174      1
# -1218.820922      1
#  356642.853685    1
# -2338.480708      1
# -7701.829257      1
# -4820.770859      1
# -435.802611       1
#  381198.918686    1
#  367794.325156    1
# -289.563679       1
# -257.733034       1
# -890.350539       1
# -2348.524271      1
# -914.167360       1
# -339.153770       1
# -2849.351119      1
# -5619.328204      1
# -448.829898       1
# -1687.038672      1
# -582.538413       1
# Name: days_employed, Length: 19351, dtype: int64
# 35    617
# 40    609
# 41    607
# 34    603
# 38    598
# 42    597
# 33    581
# 39    573
# 31    560
# 36    555
# 44    547
# 29    545
# 30    540
# 48    538
# 37    537
# 50    514
# 43    513
# 32    510
# 49    508
# 28    503
# 45    497
# 27    493
# 56    487
# 52    484
# 47    480
# 54    479
# 46    475
# 58    461
# 57    460
# 53    459
# 51    448
# 59    444
# 55    443
# 26    408
# 60    377
# 25    357
# 61    355
# 62    352
# 63    269
# 64    265
# 24    264
# 23    254
# 65    194
# 66    183
# 22    183
# 67    167
# 21    111
# 0     101
# 68     99
# 69     85
# 70     65
# 71     58
# 20     51
# 72     33
# 19     14
# 73      8
# 74      6
# 75      1
# Name: dob_years, dtype: int64
# среднее                13750
# высшее                  4718
# СРЕДНЕЕ                  772
# Среднее                  711
# неоконченное высшее      668
# ВЫСШЕЕ                   274
# Высшее                   268
# начальное                250
# Неоконченное высшее       47
# НЕОКОНЧЕННОЕ ВЫСШЕЕ       29
# НАЧАЛЬНОЕ                 17
# Начальное                 15
# ученая степень             4
# УЧЕНАЯ СТЕПЕНЬ             1
# Ученая степень             1
# Name: education, dtype: int64
# 1    15233
# 0     5260
# 2      744
# 3      282
# 4        6
# Name: education_id, dtype: int64
# женат / замужем          12380
# гражданский брак          4177
# Не женат / не замужем     2813
# в разводе                 1195
# вдовец / вдова             960
# Name: family_status, dtype: int64
# 0    12380
# 1     4177
# 4     2813
# 3     1195
# 2      960
# Name: family_status_id, dtype: int64
# F      14236
# M       7288
# XNA        1
# Name: gender, dtype: int64
# сотрудник          11119
# компаньон           5085
# пенсионер           3856
# госслужащий         1459
# безработный            2
# предприниматель        2
# в декрете              1
# студент                1
# Name: income_type, dtype: int64
# 0    19784
# 1     1741
# Name: debt, dtype: int64
# 1.128744e+05    1
# 1.339123e+05    1
# 1.820367e+05    1
# 1.224220e+05    1
# 1.982718e+05    1
# 1.091136e+05    1
# 1.643202e+05    1
# 9.105355e+04    1
# 1.043819e+05    1
# 1.091628e+06    1
# 1.002140e+05    1
# 1.849959e+05    1
# 1.675228e+05    1
# 2.003833e+05    1
# 1.337846e+05    1
# 1.484795e+05    1
# 1.060033e+05    1
# 1.843151e+05    1
# 1.267007e+05    1
# 2.762818e+05    1
# 8.992265e+04    1
# 1.008756e+05    1
# 3.739261e+05    1
# 4.525908e+04    1
# 2.081285e+05    1
# 2.515261e+05    1
# 1.022206e+05    1
# 1.259140e+05    1
# 7.399364e+04    1
# 1.265892e+05    1
#                ..
# 1.661059e+05    1
# 1.626514e+05    1
# 1.612389e+05    1
# 1.117937e+05    1
# 5.342905e+04    1
# 1.451683e+05    1
# 2.728499e+05    1
# 5.427561e+05    1
# 3.472158e+05    1
# 1.613275e+05    1
# 8.582405e+04    1
# 1.126761e+05    1
# 1.505332e+05    1
# 1.262967e+05    1
# 1.025845e+05    1
# 2.270409e+05    1
# 2.193718e+05    1
# 7.436949e+04    1
# 1.341879e+05    1
# 1.584758e+05    1
# 9.486615e+04    1
# 2.635413e+05    1
# 1.773142e+05    1
# 1.684637e+05    1
# 1.796527e+05    1
# 1.332992e+05    1
# 1.150808e+05    1
# 8.489678e+04    1
# 1.538388e+05    1
# 1.500141e+05    1
# Name: total_income, Length: 19351, dtype: int64
# свадьба                                   797
# на проведение свадьбы                     777
# сыграть свадьбу                           774
# операции с недвижимостью                  676
# покупка коммерческой недвижимости         664
# покупка жилья для сдачи                   653
# операции с жильем                         653
# операции с коммерческой недвижимостью     651
# покупка жилья                             647
# жилье                                     647
# покупка жилья для семьи                   641
# строительство собственной недвижимости    635
# недвижимость                              634
# операции со своей недвижимостью           630
# строительство жилой недвижимости          626
# покупка недвижимости                      624
# строительство недвижимости                620
# покупка своего жилья                      620
# ремонт жилью                              612
# покупка жилой недвижимости                607
# на покупку своего автомобиля              505
# заняться высшим образованием              496
# автомобиль                                495
# сделка с подержанным автомобилем          489
# свой автомобиль                           480
# на покупку подержанного автомобиля        479
# автомобили                                478
# на покупку автомобиля                     472
# приобретение автомобиля                   462
# дополнительное образование                462
# сделка с автомобилем                      455
# высшее образование                        453
# получение дополнительного образования     447
# образование                               447
# получение образования                     443
# профильное образование                    436
# получение высшего образования             426
# заняться образованием                     412
# Name: purpose, dtype: int64

# %% [markdown]
# ### Вывод

# %% [markdown]
# Таблица состоит из 12 столбцов. Всего в таблице используется 4 типа данных : float64(2), int64(5), object(5). В разных столбцах попадаются пустые значения и дубликаты.
# #### Рассмотрим странные значения по каждому из столбцов :
#     1.children
#         а) Значение '-1' повторившееся 47 раз указывкет на некорректный ввод, скорее всего имелось в виду значение '1'.
#         Скорее всего это некорректно записанное в следствии технических проблем значение '1'.
#         б) Значение '20' повторившееся 76 раз слишком велико и никак не вписывается в логику распределения детей по категориям.
#         Скорее всего это некорректно записанное в следствии технических проблем значение '2'.
#
#     2.days_employed
#         a) Не может быть отрицательных значений количества дней.
#         Скорее всего вызваны некорректным автозаполнением.
#     3.education
#         а) Замечены дубликаты как следствие разного регистра.
#         Челоечесий фактор. Возможно данные заполняли разные люди в разное время, а также никто не привел значения к одному виду
#
#     4.gender
#         a) Странное значение "XNA" в количестве 1шт. Можно удалить или неучитывать.
#         Неопределенное значение, возможно - случайность, вызванная человеческим фактором
#
#     5.purposre
#         a) Много повторяющихся по смыслу значений.
#         Челоечесий фактор. Возможно данные заполняли разные люди в разное время, а также никто не привел значения к одному виду

# %% [markdown]
# #### Варианты исправления неточностей
#     1.children
#         а) замена '-1' на '1'
#         б) замена '20' на '2', либо удаление таких значений
#
#     2.days_employed
#         a) сделать все значение положитьельными (получить модуль всех значений)
#
#     3.education
#         а) Произвести замену
#
#     4.gender
#         a) Удалить или не учитывать
#
#     5.purposre
#         a) Провести лемматизацию, свести имеющиеся цели к наиболле общим

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# ### Обработка пропусков

# %%
#Рассмотрим уникальные значения в столбцах
for i in columns_names:                         
    print(i)
    print(client_data[i].unique())
    print()
# использовав метотод uniqe() можно убедиться, что во всех столбцах кроме 'days_employed' 
# и 'total_income' нет уникальных значений None и Nan
# Out:
# children
# [ 1  0  3  2 -1  4 20  5]
#
# days_employed
# [-8437.67302776 -4024.80375385 -5623.42261023 ... -2113.3468877
#  -3112.4817052  -1984.50758853]
#
# dob_years
# [42 36 33 32 53 27 43 50 35 41 40 65 54 56 26 48 24 21 57 67 28 63 62 47
#  34 68 25 31 30 20 49 37 45 61 64 44 52 46 23 38 39 51  0 59 29 60 55 58
#  71 22 73 66 69 19 72 70 74 75]
#
# education
# ['высшее' 'среднее' 'Среднее' 'СРЕДНЕЕ' 'ВЫСШЕЕ' 'неоконченное высшее'
#  'начальное' 'Высшее' 'НЕОКОНЧЕННОЕ ВЫСШЕЕ' 'Неоконченное высшее'
#  'НАЧАЛЬНОЕ' 'Начальное' 'Ученая степень' 'УЧЕНАЯ СТЕПЕНЬ'
#  'ученая степень']
#
# education_id
# [0 1 2 3 4]
#
# family_status
# ['женат / замужем' 'гражданский брак' 'вдовец / вдова' 'в разводе'
#  'Не женат / не замужем']
#
# family_status_id
# [0 1 2 3 4]
#
# gender
# ['F' 'M' 'XNA']
#
# income_type
# ['сотрудник' 'пенсионер' 'компаньон' 'госслужащий' 'безработный'
#  'предприниматель' 'студент' 'в декрете']
#
# debt
# [0 1]
#
# total_income
# [253875.6394526  112080.01410244 145885.95229686 ...  89672.56115303
#  244093.05050043  82047.41889948]
#
# purpose
# ['покупка жилья' 'приобретение автомобиля' 'дополнительное образование'
#  'сыграть свадьбу' 'операции с жильем' 'образование'
#  'на проведение свадьбы' 'покупка жилья для семьи' 'покупка недвижимости'
#  'покупка коммерческой недвижимости' 'покупка жилой недвижимости'
#  'строительство собственной недвижимости' 'недвижимость'
#  'строительство недвижимости' 'на покупку подержанного автомобиля'
#  'на покупку своего автомобиля' 'операции с коммерческой недвижимостью'
#  'строительство жилой недвижимости' 'жилье'
#  'операции со своей недвижимостью' 'автомобили' 'заняться образованием'
#  'сделка с подержанным автомобилем' 'получение образования' 'автомобиль'
#  'свадьба' 'получение дополнительного образования' 'покупка своего жилья'
#  'операции с недвижимостью' 'получение высшего образования'
#  'свой автомобиль' 'сделка с автомобилем' 'профильное образование'
#  'высшее образование' 'покупка жилья для сдачи' 'на покупку автомобиля'
#  'ремонт жилью' 'заняться высшим образованием']

# %%
                       # Осталось рассмотреть 'days_employed' и 'total_income'.
client_data.count()  # Рассмотртим общее количество значений в столбцах. Видно, что в 
                            # 'days_employed' и 'total_income' есть пропуски.
# Out:
# children            21525
# days_employed       19351
# dob_years           21525
# education           21525
# education_id        21525
# family_status       21525
# family_status_id    21525
# gender              21525
# income_type         21525
# debt                21525
# total_income        19351
# purpose             21525
# dtype: int64

# %%
print('Количество пропущенных значений в days_employed: {}'.format(client_data['days_employed'].isnull().sum()))
# Out:
# Количество пропущенных значений в days_employed: 2174

# %%
print('Количество пропущенных значений в total_income: {}'.format(client_data['total_income'].isnull().sum()))
# Out:
# Количество пропущенных значений в total_income: 2174

# %%
client_data[client_data['days_employed'].isnull() == True] #выведем на экран, все строки, где отсутствует информация 
                                                                   # об общем трудовом стаже
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 12            0            NaN         65              среднее             1
# 26            0            NaN         41              среднее             1
# 29            0            NaN         63              среднее             1
# 41            0            NaN         50              среднее             1
# 55            0            NaN         54              среднее             1
# 65            0            NaN         21              среднее             1
# 67            0            NaN         52               высшее             0
# 72            1            NaN         32               высшее             0
# 82            2            NaN         50               высшее             0
# 83            0            NaN         52              среднее             1
# 90            2            NaN         35               высшее             0
# 94            1            NaN         34               высшее             0
# 96            0            NaN         44              СРЕДНЕЕ             1
# 97            0            NaN         47               высшее             0
# 120           0            NaN         46              среднее             1
# 121           0            NaN         29               высшее             0
# 135           0            NaN         27              среднее             1
# 141           0            NaN         39              среднее             1
# 145           0            NaN         62              среднее             1
# 174           0            NaN         55               высшее             0
# 181           0            NaN         26              среднее             1
# 189           1            NaN         30              среднее             1
# 205           1            NaN         31               высшее             0
# 220           1            NaN         23  неоконченное высшее             2
# 241           0            NaN         47              среднее             1
# 242           0            NaN         58              среднее             1
# 247           1            NaN         60               высшее             0
# 250           0            NaN         54               высшее             0
# 264           2            NaN         40              среднее             1
# 278           1            NaN         23              Среднее             1
# ...         ...            ...        ...                  ...           ...
# 21226         3            NaN         38              среднее             1
# 21242         1            NaN         33               высшее             0
# 21251         0            NaN         57  неоконченное высшее             2
# 21258         1            NaN         40              среднее             1
# 21268         1            NaN         44               высшее             0
# 21271         2            NaN         42              среднее             1
# 21281         1            NaN         30               высшее             0
# 21294         0            NaN         45               ВЫСШЕЕ             0
# 21300         2            NaN         45              Среднее             1
# 21305         0            NaN         59              среднее             1
# 21308         0            NaN         48              среднее             1
# 21311         0            NaN         49              среднее             1
# 21321         0            NaN         56              Среднее             1
# 21350         0            NaN         21              среднее             1
# 21364         0            NaN         50              среднее             1
# 21369         2            NaN         42              среднее             1
# 21390        20            NaN         53              среднее             1
# 21391         0            NaN         52              среднее             1
# 21407         1            NaN         36              среднее             1
# 21414         0            NaN         65              среднее             1
# 21415         0            NaN         54              среднее             1
# 21423         0            NaN         63              среднее             1
# 21426         0            NaN         49              среднее             1
# 21432         1            NaN         38  неоконченное высшее             2
# 21463         1            NaN         35               высшее             0
# 21489         2            NaN         47              Среднее             1
# 21495         1            NaN         50              среднее             1
# 21497         0            NaN         48               ВЫСШЕЕ             0
# 21502         1            NaN         42              среднее             1
# 21510         2            NaN         28              среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 12          гражданский брак                 1      M    пенсионер     0
# 26           женат / замужем                 0      M  госслужащий     0
# 29     Не женат / не замужем                 4      F    пенсионер     0
# 41           женат / замужем                 0      F  госслужащий     0
# 55          гражданский брак                 1      F    пенсионер     1
# 65     Не женат / не замужем                 4      M    компаньон     0
# 67           женат / замужем                 0      F    пенсионер     0
# 72           женат / замужем                 0      M  госслужащий     0
# 82           женат / замужем                 0      F    сотрудник     0
# 83           женат / замужем                 0      M    сотрудник     0
# 90           женат / замужем                 0      F    сотрудник     0
# 94          гражданский брак                 1      F    компаньон     0
# 96           женат / замужем                 0      F    сотрудник     0
# 97           женат / замужем                 0      F    сотрудник     0
# 120          женат / замужем                 0      F    сотрудник     0
# 121          женат / замужем                 0      F    компаньон     0
# 135          женат / замужем                 0      M    компаньон     0
# 141         гражданский брак                 1      M    сотрудник     0
# 145          женат / замужем                 0      M    пенсионер     0
# 174           вдовец / вдова                 2      F    компаньон     0
# 181         гражданский брак                 1      F    компаньон     1
# 189    Не женат / не замужем                 4      F    сотрудник     0
# 205          женат / замужем                 0      F    сотрудник     0
# 220         гражданский брак                 1      F    компаньон     0
# 241          женат / замужем                 0      M    сотрудник     0
# 242          женат / замужем                 0      F  госслужащий     0
# 247          женат / замужем                 0      F    пенсионер     1
# 250          женат / замужем                 0      F    сотрудник     0
# 264                в разводе                 3      F    сотрудник     0
# 278         гражданский брак                 1      F    сотрудник     1
# ...                      ...               ...    ...          ...   ...
# 21226       гражданский брак                 1      M    сотрудник     0
# 21242  Не женат / не замужем                 4      F  госслужащий     0
# 21251       гражданский брак                 1      F    сотрудник     0
# 21258  Не женат / не замужем                 4      M    сотрудник     0
# 21268       гражданский брак                 1      F  госслужащий     0
# 21271       гражданский брак                 1      M    сотрудник     1
# 21281        женат / замужем                 0      F    сотрудник     0
# 21294        женат / замужем                 0      F    сотрудник     0
# 21300       гражданский брак                 1      M    компаньон     0
# 21305  Не женат / не замужем                 4      F    пенсионер     0
# 21308        женат / замужем                 0      F    компаньон     0
# 21311        женат / замужем                 0      F    пенсионер     0
# 21321        женат / замужем                 0      F    пенсионер     0
# 21350  Не женат / не замужем                 4      M    компаньон     0
# 21364        женат / замужем                 0      M    сотрудник     0
# 21369              в разводе                 3      M    компаньон     0
# 21390        женат / замужем                 0      M    компаньон     0
# 21391        женат / замужем                 0      F    компаньон     0
# 21407        женат / замужем                 0      F    компаньон     0
# 21414        женат / замужем                 0      F    пенсионер     0
# 21415        женат / замужем                 0      F    пенсионер     0
# 21423        женат / замужем                 0      M    пенсионер     0
# 21426        женат / замужем                 0      F    сотрудник     1
# 21432  Не женат / не замужем                 4      F    сотрудник     0
# 21463       гражданский брак                 1      M    сотрудник     0
# 21489        женат / замужем                 0      M    компаньон     0
# 21495       гражданский брак                 1      F    сотрудник     0
# 21497        женат / замужем                 0      F    компаньон     0
# 21502        женат / замужем                 0      F    сотрудник     0
# 21510        женат / замужем                 0      F    сотрудник     0
#
#        total_income                                 purpose
# 12              NaN                         сыграть свадьбу
# 26              NaN                             образование
# 29              NaN        строительство жилой недвижимости
# 41              NaN        сделка с подержанным автомобилем
# 55              NaN                         сыграть свадьбу
# 65              NaN   операции с коммерческой недвижимостью
# 67              NaN                 покупка жилья для семьи
# 72              NaN   операции с коммерческой недвижимостью
# 82              NaN                                   жилье
# 83              NaN                                   жилье
# 90              NaN                       операции с жильем
# 94              NaN                   на проведение свадьбы
# 96              NaN              покупка жилой недвижимости
# 97              NaN                  профильное образование
# 120             NaN                      высшее образование
# 121             NaN                              автомобиль
# 135             NaN                                   жилье
# 141             NaN                                 свадьба
# 145             NaN              строительство недвижимости
# 174             NaN                         свой автомобиль
# 181             NaN                 покупка жилья для семьи
# 189             NaN                         свой автомобиль
# 205             NaN      на покупку подержанного автомобиля
# 220             NaN                         сыграть свадьбу
# 241             NaN  строительство собственной недвижимости
# 242             NaN                    покупка своего жилья
# 247             NaN            заняться высшим образованием
# 250             NaN        сделка с подержанным автомобилем
# 264             NaN                            недвижимость
# 278             NaN                              автомобиль
# ...             ...                                     ...
# 21226           NaN                   получение образования
# 21242           NaN  строительство собственной недвижимости
# 21251           NaN                                 свадьба
# 21258           NaN                       операции с жильем
# 21268           NaN                   на проведение свадьбы
# 21271           NaN         операции со своей недвижимостью
# 21281           NaN       покупка коммерческой недвижимости
# 21294           NaN                      высшее образование
# 21300           NaN   получение дополнительного образования
# 21305           NaN  строительство собственной недвижимости
# 21308           NaN                 покупка жилья для сдачи
# 21311           NaN                 покупка жилья для сдачи
# 21321           NaN                операции с недвижимостью
# 21350           NaN                   на покупку автомобиля
# 21364           NaN         операции со своей недвижимостью
# 21369           NaN              покупка жилой недвижимости
# 21390           NaN              покупка жилой недвижимости
# 21391           NaN                 покупка жилья для семьи
# 21407           NaN        строительство жилой недвижимости
# 21414           NaN                    покупка своего жилья
# 21415           NaN                       операции с жильем
# 21423           NaN                    сделка с автомобилем
# 21426           NaN                            недвижимость
# 21432           NaN                       операции с жильем
# 21463           NaN                   на проведение свадьбы
# 21489           NaN                    сделка с автомобилем
# 21495           NaN                                 свадьба
# 21497           NaN              строительство недвижимости
# 21502           NaN        строительство жилой недвижимости
# 21510           NaN                 приобретение автомобиля
#
# [2174 rows x 12 columns]

# %%
client_data['days_employed'] = abs(client_data['days_employed']) # сделаем трудовой стаж положительным во всех ячейках

# %%
mean_days_employed = client_data['days_employed'].mean()

# %%
median_total_income = client_data['total_income'].median()      #использовал median с учетом большой разницы в доходах

# %%
# заменим отсутствующие значения на средние
client_data['days_employed'] = client_data['days_employed'].fillna(mean_days_employed)

# %%
# заменим отсутствующие значения на медианные
client_data['total_income'] = client_data['total_income'].fillna(median_total_income)

# %%
# еще раз проверим пропуски'
print('Количество пропущенных значений в days_employed: {}'.format(client_data['days_employed'].isnull().sum())) 
print('Количество пропущенных значений в total_income: {}'.format(client_data['total_income'].isnull().sum()))
# Out:
# Количество пропущенных значений в days_employed: 0
# Количество пропущенных значений в total_income: 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# Для поиска пропусков я сначала использовал метод unique(), чтобы среди уникальных значений в столбцах отыскать None и NaN, однако этого метода оказалось недостаточно, т.к. 'days_employed' и 'total_income' имели слишком много уникальных значений для
# анализа, однако я точно убедился, что во всех столбцах кроме этих двух нет пропусков. Далее с помощью .isnull().sum() я подсчитал кол-во пропусков, и оно оказалось одинаково для обоих столбцов. Это значит, что пропуски в этих столбцах в одних и тех же строках, в чем можно убидться, если вывести на экран строки с NaN. Данные пропуски являются неслучайными, т.к. взаимозависимы.
#     Возможно, чтобы посчитать значения total_income требовуется значения days_employed, поэтому они и пропущены вместе. Либо часть клиентов не давало согласия на сбор таких данных.
#     Пропуски количественных переменных теперь заполнены средним значением ('days_employed') и медианным ('total_income'). Перед
# заполнением, для подсчета средних значений я избавился от отрицательности в 'days_employed' с помощью abs.

# %% [markdown]
# ### Замена типа данных

# %%
client_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       21525 non-null float64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        21525 non-null float64
# purpose             21525 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# #### Заменим тип данных float в days_employed и total_income на int

# %%
client_data['days_employed'] = client_data['days_employed'].astype('int')

# %%
client_data['total_income'] = client_data['total_income'].astype('int')

# %%
client_data.info() #убедимся, что типы данных изменены
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       21525 non-null int64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        21525 non-null int64
# purpose             21525 non-null object
# dtypes: int64(7), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Вывод

# %% [markdown]
# Теперь столбцы 'days_employed' и 'total_income' имеют целочисленный тип данных. Для перевода я выбрал метод astype() т.к. он
# может переводить float в int.

# %% [markdown]
# ### Обработка дубликатов

# %%
client_data['education'].value_counts() # рассмотрим значения в таблице "education"
# Out:
# среднее                13750
# высшее                  4718
# СРЕДНЕЕ                  772
# Среднее                  711
# неоконченное высшее      668
# ВЫСШЕЕ                   274
# Высшее                   268
# начальное                250
# Неоконченное высшее       47
# НЕОКОНЧЕННОЕ ВЫСШЕЕ       29
# НАЧАЛЬНОЕ                 17
# Начальное                 15
# ученая степень             4
# УЧЕНАЯ СТЕПЕНЬ             1
# Ученая степень             1
# Name: education, dtype: int64

# %%
#заменим значения
client_data['education'] = client_data['education'].replace(['СРЕДНЕЕ','Среднее'] , 'среднее')   
client_data['education'] = client_data['education'].replace(['ВЫСШЕЕ','Высшее'] , 'высшее')
client_data['education'] = client_data['education'].replace(['Неоконченное высшее','НЕОКОНЧЕННОЕ ВЫСШЕЕ'] , 'неоконченное высшее')
client_data['education'] = client_data['education'].replace(['Начальное','НАЧАЛЬНОЕ'] , 'начальное')
client_data['education'] = client_data['education'].replace(['Ученая степень','УЧЕНАЯ СТЕПЕНЬ'] , 'ученая степень')

# %%
client_data['education'].value_counts() #рассмотрим результат замены
# Out:
# среднее                15233
# высшее                  5260
# неоконченное высшее      744
# начальное                282
# ученая степень             6
# Name: education, dtype: int64

# %%
print('Дубликатов в таблице : {}'.format(client_data.duplicated().sum())) #проверим на дубликаты
# Out:
# Дубликатов в таблице : 71

# %%
client_data = client_data.drop_duplicates().reset_index(drop = True) # удалим дубликаты

# %%
print('Дубликатов в таблице : {}'.format(client_data.duplicated().sum()))
# Out:
# Дубликатов в таблице : 0

# %%
#избавимся от отрицательного значения (-1) для детей
client_data['children'] = client_data['children'].replace(-1, 1)

# %%
print(client_data['children'].value_counts())  # проверим, что отрицательных значений не осталось
# Out:
# 0     14091
# 1      4855
# 2      2052
# 3       330
# 20       76
# 4        41
# 5         9
# Name: children, dtype: int64

# %% [markdown]
# ### Вывод

# %% [markdown]
# На данном этапе я избавился от многообразия значений в стлбце 'education' и привел их к пяти уникальным значениям, после чего проверил таблицу на дубликаты и избавился от них. Я не приводил занчения к одному регистру, а просто заменил ибыточные значений
# на более универсальные методом replace(). В данной ситуации этот метод показался мне проще и удобней. Также заменил значения -1 на 1 в 'children'. Скорее всего отрицательное число появилось в следствии технической ошибки во время автозаполнения данных.

# %% [markdown]
# ### Лемматизация

# %%
from pymystem3 import Mystem
from collections import Counter

# %%
m = Mystem()
for index in range(len(client_data['purpose'])):               #выделите леммы в значениях столбца с целями получения кредита
    lemma = m.lemmatize(client_data.loc[index,'purpose'])           
    print(Counter(lemma))
# Out:
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({'получение': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'дополнительный': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'дополнительный': 1, 'образование': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'дополнительный': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'дополнительный': 1, 'образование': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'дополнительный': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'дополнительный': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({'получение': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({'получение': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'дополнительный': 1, 'образование': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'получение': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'получение': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'получение': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'получение': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'дополнительный': 1, 'образование': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'дополнительный': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'получение': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'получение': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'получение': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'дополнительный': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({'получение': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# ...
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'получение': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'высокий': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'дополнительный': 1, 'образование': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({'получение': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({'получение': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'дополнительный': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({'профильный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'дополнительный': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({'образование': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'дополнительный': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'заниматься': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'собственный': 1, 'недвижимость': 1, '\n': 1})
# Counter({'получение': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'высокий': 1, 'образование': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'со': 1, 'свой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'проведение': 1, 'свадьба': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({'ремонт': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({'свой': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({'автомобиль': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'подержать': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'семья': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'операция': 1, 'с': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({'жилье': 1, '\n': 1})
# Counter({' ': 2, 'строительство': 1, 'жилой': 1, 'недвижимость': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'дополнительный': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({'сыграть': 1, ' ': 1, 'свадьба': 1, '\n': 1})
# Counter({'свадьба': 1, '\n': 1})
# Counter({' ': 3, 'сделка': 1, 'с': 1, 'подержанный': 1, 'автомобиль': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'недвижимость': 1, '\n': 1})
# Counter({'приобретение': 1, ' ': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 3, 'покупка': 1, 'жилье': 1, 'для': 1, 'сдача': 1, '\n': 1})
# Counter({' ': 2, 'получение': 1, 'дополнительный': 1, 'образование': 1, '\n': 1})
# Counter({'покупка': 1, ' ': 1, 'жилье': 1, '\n': 1})
# Counter({'строительство': 1, ' ': 1, 'недвижимость': 1, '\n': 1})
# Counter({'заниматься': 1, ' ': 1, 'образование': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'свой': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'покупка': 1, 'коммерческий': 1, 'недвижимость': 1, '\n': 1})
# Counter({' ': 2, 'операция': 1, 'с': 1, 'жилье': 1, '\n': 1})
# Counter({' ': 2, 'сделка': 1, 'с': 1, 'автомобиль': 1, '\n': 1})
# Counter({'недвижимость': 1, '\n': 1})
# Counter({' ': 3, 'на': 1, 'покупка': 1, 'свой': 1, 'автомобиль': 1, '\n': 1})
# Counter({' ': 2, 'на': 1, 'покупка': 1, 'автомобиль': 1, '\n': 1})

# %%
lemmas = []
for index in range(len(client_data['purpose'])):
    lemma = m.lemmatize(client_data.loc[index,'purpose'])            #получим лемму для строки
    if 'свадьба' in lemma:                                           # найдем ключивые слова и перепишем по ним значения на 
        client_data.loc[index, 'purpose'] = 'расходы на свадьбу'     # универсальные
    if ('недвижимость' in lemma) or ('жилье' in lemma):
        client_data.loc[index, 'purpose'] = 'операции с недвижимостью'
    if 'автомобиль' in lemma:                                            
        client_data.loc[index, 'purpose'] = 'расходы на автомобиль'
    if 'образование' in lemma:                                           
        client_data.loc[index, 'purpose'] = 'образование'

# %%
client_data['purpose'].value_counts()  #проверим резульат
# Out:
# операции с недвижимостью    10811
# расходы на автомобиль        4306
# образование                  4013
# расходы на свадьбу           2324
# Name: purpose, dtype: int64

# %%
Counter(client_data['purpose'])
# Out:
# Counter({'операции с недвижимостью': 10811,
#          'расходы на автомобиль': 4306,
#          'образование': 4013,
#          'расходы на свадьбу': 2324})

# %%
#на следующих этапах, при создании pivot tables обнаружил дубликты
client_data.duplicated().sum()
# Out:
# 334

# %%
#удалим дубликаты
client_data = client_data.drop_duplicates().reset_index(drop = True)

# %%
#проверим наличие дубликатов
client_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# Значения в столбце 'purpose' повторялись по смыслу. Сначала я вывел список лемм для всех значний, чтобы понять ключевые слова-леммы, с помощью которых можно избавиться от избыточных значений. Я выделил ключевые слова из лемм, и в цикле разбивал каждое значение столбца на леммы, и если среди них попадалсь ключевая лемма, то цикл перезаписывал значение столбца на одно из четырех, которые я выделил ( операции с недвижимостью, расходы на автомобиль, образование, расходы на свадьбу). Я выделил именно леммы ( 'свадьба', 'недвижимость' и 'жилье', 'автомобиль', 'образование' ) т.к. они встречались в строках чаще всего и на мой взгяд логически указывали на принодлежность к одной из четырех базовых категорий.

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# #### Выделение словарей

# %%
client_data_log = client_data[['children', 'days_employed', 'dob_years', 'education_id', 'family_status_id', 'gender', 'income_type', 'debt', 'total_income', 'purpose' ]]
education_dict = client_data[['education_id', 'education' ]]
family_status_dict = client_data[['family_status_id', 'family_status']]

education_dict = education_dict.drop_duplicates().reset_index( drop = True)           #выделим словарь для образования
family_status_dict = family_status_dict.drop_duplicates().reset_index( drop = True)   #выделим словарь для семейного статуса

# %%
education_dict.sort_values( by = 'education_id').head(10)
# Out:
#    education_id            education
# 0             0               высшее
# 1             1              среднее
# 2             2  неоконченное высшее
# 3             3            начальное
# 4             4       ученая степень

# %%
family_status_dict.sort_values( by = 'family_status_id').head(10)
# Out:
#    family_status_id          family_status
# 0                 0        женат / замужем
# 1                 1       гражданский брак
# 2                 2         вдовец / вдова
# 3                 3              в разводе
# 4                 4  Не женат / не замужем

# %% [markdown]
# #### Категоризация столбца 'total_income'

# %%
#изучим статистику по столбцу
client_data['total_income'].describe()
# Out:
# count    2.112000e+04
# mean     1.655452e+05
# std      9.875988e+04
# min      2.066700e+04
# 25%      1.068090e+05
# 50%      1.450170e+05
# 75%      1.969560e+05
# max      2.265604e+06
# Name: total_income, dtype: float64

# %%
#для категоризации используем процентели 25%, 50% и 75% 

# функия определения категории
def income_category(value):
    if value < 107000:
        return 'низкий'
    if 107000 < value < 195000:
        return 'средний'
    return 'высокий'

# %%
#добавим столбец с категорией дохода в таблицу
client_data.loc[:,'income_category'] = client_data.loc[:,'total_income'].apply(income_category)

# %%
client_data.head(10)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1           8437         42    высшее             0
# 1         1           4024         36   среднее             1
# 2         0           5623         33   среднее             1
# 3         3           4124         32   среднее             1
# 4         0         340266         53   среднее             1
# 5         0            926         27    высшее             0
# 6         0           2879         43    высшее             0
# 7         0            152         50   среднее             1
# 8         2           6929         35    высшее             0
# 9         0           2188         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# 2   женат / замужем                 0      M   сотрудник     0        145885
# 3   женат / замужем                 0      M   сотрудник     0        267628
# 4  гражданский брак                 1      F   пенсионер     0        158616
# 5  гражданский брак                 1      M   компаньон     0        255763
# 6   женат / замужем                 0      F   компаньон     0        240525
# 7   женат / замужем                 0      M   сотрудник     0        135823
# 8  гражданский брак                 1      F   сотрудник     0         95856
# 9   женат / замужем                 0      M   сотрудник     0        144425
#
#                     purpose income_category
# 0  операции с недвижимостью         высокий
# 1     расходы на автомобиль         средний
# 2  операции с недвижимостью         средний
# 3               образование         высокий
# 4        расходы на свадьбу         средний
# 5  операции с недвижимостью         высокий
# 6  операции с недвижимостью         высокий
# 7               образование         средний
# 8        расходы на свадьбу          низкий
# 9  операции с недвижимостью         средний

# %% [markdown]
# ### Вывод

# %% [markdown]
# Я создал словари для 'education' и  'family_status_id'. Добавил столбец с категорией дохода в исходную таблицу.

# %% [markdown]
# ### Шаг 3. Ответьте на вопросы

# %% [markdown]
# - Есть ли зависимость между наличием детей и возвратом кредита в срок?

# %%
debt_and_chidren = client_data[['children', 'debt']]   #создадим неизбыточную таблицу для ответа на вопрос
#print(debt_and_chidren.head(10))

#подсчитаем количество клиентов с детьми, которые имели задолженности :
with_kids = debt_and_chidren.loc[(debt_and_chidren['children'] != 0) & (debt_and_chidren['debt'] == 1), 'children'].count()
print('Количество клиентов с детьми, которые имели задолженности: {}'.format(with_kids)) 
#подсчитаем количество клиентов с без детей, которые имели задолженности :
without_kids = debt_and_chidren.loc[(debt_and_chidren['children'] == 0) & (debt_and_chidren['debt'] == 1), 'children'].count()
print('Количество клиентов без детей, которые имели задолженности: {}'.format(without_kids)) 
# отношение  с детьми и долгами/без детей с долгами

ratio_kids = without_kids / with_kids
print('Должников без детей больше должников с детьми в {:.2f} раз'.format(ratio_kids))
# Out:
# Количество клиентов с детьми, которые имели задолженности: 678
# Количество клиентов без детей, которые имели задолженности: 1061
# Должников без детей больше должников с детьми в 1.56 раз

# %%
client_data.columns
# Out:
# Index(['children', 'days_employed', 'dob_years', 'education', 'education_id',
#        'family_status', 'family_status_id', 'gender', 'income_type', 'debt',
#        'total_income', 'purpose', 'income_category'],
#       dtype='object')

# %%
client_data.duplicated().sum()
# Out:
# 0

# %%
# посмотрим распределение клиентов по детям без долгов
client_data.loc[ client_data ['debt']== 0, 'children'].value_counts()
# Out:
# 0     12768
# 1      4353
# 2      1845
# 3       302
# 20       68
# 4        36
# 5         9
# Name: children, dtype: int64

# %%
# посмотрим распределение клиентов по детям с долгами
client_data.loc[ client_data ['debt']== 1, 'children'].value_counts()
# Out:
# 0     1061
# 1      445
# 2      194
# 3       27
# 20       8
# 4        4
# Name: children, dtype: int64

# %%
client_data[client_data['debt'] == 1]
# Out:
#        children  days_employed  dob_years  education  education_id  \
# 14            0           1844         56     высшее             0
# 32            0           4649         34    среднее             1
# 38            0            597         25     высшее             0
# 55            0          66914         54    среднее             1
# 75            1           2953         38    среднее             1
# 93            1           1446         32    среднее             1
# 100           0            605         49    среднее             1
# 114           0           1599         26     высшее             0
# 124           0           1080         38    среднее             1
# 147           0           5772         47    среднее             1
# 153           1            132         20    среднее             1
# 157           0         348414         38    среднее             1
# 164           2           2357         27     высшее             0
# 181           0          66914         26    среднее             1
# 183           1            166         35     высшее             0
# 185           0           5026         32    среднее             1
# 202           1           1575         38    среднее             1
# 213           1            703         38     высшее             0
# 218           1           2924         34    среднее             1
# 230           1           2049         28    среднее             1
# 231           1            144         41    среднее             1
# 247           1          66914         60     высшее             0
# 269           2            146         37    среднее             1
# 272           0           5538         35  начальное             3
# 278           1          66914         23    среднее             1
# 285           0            877         50    среднее             1
# 287           0           1382         47    среднее             1
# 297           0            471         45    среднее             1
# 301           0            848         53    среднее             1
# 305           2           7381         36    среднее             1
# ...         ...            ...        ...        ...           ...
# 20919         0            856         27    среднее             1
# 20923         0            505         42    среднее             1
# 20927         0            592         25    среднее             1
# 20935         1            578         45    среднее             1
# 20942         0         393646         63    среднее             1
# 20958         0            973         32    среднее             1
# 20969         0           1328         46     высшее             0
# 20974         0           1381         49    среднее             1
# 20980         0         367527         59     высшее             0
# 20988         0           2461         33    среднее             1
# 20992         0           2095         26     высшее             0
# 21007         2           2082         28    среднее             1
# 21016         1            108         40    среднее             1
# 21020         0         335228         55    среднее             1
# 21022         0          66914         49    среднее             1
# 21023         2           1050         42    среднее             1
# 21026         0            170         41    среднее             1
# 21041         0            491         25    среднее             1
# 21047         1           1544         24    среднее             1
# 21052         2           2247         23    среднее             1
# 21053         0            448         49    среднее             1
# 21062         0           1029         37    среднее             1
# 21071         0         365213         52    среднее             1
# 21079         2           2917         38  начальное             3
# 21082         0           1614         36    среднее             1
# 21090         0            960         39    среднее             1
# 21106         0            612         29     высшее             0
# 21110         1            467         28    среднее             1
# 21117         1           2113         38    среднее             1
# 21118         3           3112         38    среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 14          гражданский брак                 1      F    компаньон     1
# 32          гражданский брак                 1      F    сотрудник     1
# 38     Не женат / не замужем                 4      M    сотрудник     1
# 55          гражданский брак                 1      F    пенсионер     1
# 75           женат / замужем                 0      M    сотрудник     1
# 93           женат / замужем                 0      M    сотрудник     1
# 100           вдовец / вдова                 2      F    сотрудник     1
# 114          женат / замужем                 0      F    сотрудник     1
# 124          женат / замужем                 0      F    сотрудник     1
# 147          женат / замужем                 0      F  госслужащий     1
# 153          женат / замужем                 0      M    компаньон     1
# 157          женат / замужем                 0      F    пенсионер     1
# 164          женат / замужем                 0      F    сотрудник     1
# 181         гражданский брак                 1      F    компаньон     1
# 183         гражданский брак                 1      M    компаньон     1
# 185         гражданский брак                 1      M    сотрудник     1
# 202          женат / замужем                 0      F    сотрудник     1
# 213         гражданский брак                 1      M    сотрудник     1
# 218          женат / замужем                 0      F    сотрудник     1
# 230         гражданский брак                 1      M    компаньон     1
# 231          женат / замужем                 0      F    сотрудник     1
# 247          женат / замужем                 0      F    пенсионер     1
# 269          женат / замужем                 0      F    сотрудник     1
# 272         гражданский брак                 1      M    сотрудник     1
# 278         гражданский брак                 1      F    сотрудник     1
# 285          женат / замужем                 0      M    компаньон     1
# 287          женат / замужем                 0      M    сотрудник     1
# 297          женат / замужем                 0      F    сотрудник     1
# 301          женат / замужем                 0      M    сотрудник     1
# 305                в разводе                 3      F    сотрудник     1
# ...                      ...               ...    ...          ...   ...
# 20919        женат / замужем                 0      M    компаньон     1
# 20923  Не женат / не замужем                 4      F    сотрудник     1
# 20927       гражданский брак                 1      M    сотрудник     1
# 20935        женат / замужем                 0      M    сотрудник     1
# 20942        женат / замужем                 0      M    пенсионер     1
# 20958  Не женат / не замужем                 4      M    компаньон     1
# 20969  Не женат / не замужем                 4      M    сотрудник     1
# 20974       гражданский брак                 1      M    сотрудник     1
# 20980        женат / замужем                 0      F    пенсионер     1
# 20988        женат / замужем                 0      M    сотрудник     1
# 20992  Не женат / не замужем                 4      M    сотрудник     1
# 21007        женат / замужем                 0      F    сотрудник     1
# 21016        женат / замужем                 0      M    сотрудник     1
# 21020              в разводе                 3      F    пенсионер     1
# 21022        женат / замужем                 0      F    сотрудник     1
# 21023        женат / замужем                 0      F    сотрудник     1
# 21026        женат / замужем                 0      F    сотрудник     1
# 21041  Не женат / не замужем                 4      M    компаньон     1
# 21047        женат / замужем                 0      F    сотрудник     1
# 21052        женат / замужем                 0      F    сотрудник     1
# 21053        женат / замужем                 0      F    сотрудник     1
# 21062  Не женат / не замужем                 4      M    компаньон     1
# 21071        женат / замужем                 0      F    пенсионер     1
# 21079       гражданский брак                 1      F    сотрудник     1
# 21082        женат / замужем                 0      F    сотрудник     1
# 21090       гражданский брак                 1      M    компаньон     1
# 21106       гражданский брак                 1      F    сотрудник     1
# 21110        женат / замужем                 0      F    сотрудник     1
# 21117       гражданский брак                 1      M    сотрудник     1
# 21118        женат / замужем                 0      M    сотрудник     1
#
#        total_income                   purpose income_category
# 14           165127  операции с недвижимостью         средний
# 32           139057        расходы на свадьбу         средний
# 38           192247               образование         средний
# 55           145017        расходы на свадьбу         средний
# 75            81935  операции с недвижимостью          низкий
# 93           331139     расходы на автомобиль         высокий
# 100          176384  операции с недвижимостью         средний
# 114          143471  операции с недвижимостью         средний
# 124          175046  операции с недвижимостью         средний
# 147           74535  операции с недвижимостью          низкий
# 153          134750  операции с недвижимостью         средний
# 157          113560     расходы на автомобиль         средний
# 164          369587     расходы на автомобиль         высокий
# 181          145017  операции с недвижимостью         средний
# 183          272193               образование         высокий
# 185          160905               образование         средний
# 202           90960  операции с недвижимостью          низкий
# 213          231389     расходы на автомобиль         высокий
# 218          213214     расходы на автомобиль         высокий
# 230          188585        расходы на свадьбу         средний
# 231          112090  операции с недвижимостью         средний
# 247          145017               образование         средний
# 269           80334     расходы на автомобиль          низкий
# 272          123814               образование         средний
# 278          145017     расходы на автомобиль         средний
# 285           81863               образование          низкий
# 287          143042  операции с недвижимостью         средний
# 297          143383  операции с недвижимостью         средний
# 301          174396  операции с недвижимостью         средний
# 305           45033  операции с недвижимостью          низкий
# ...             ...                       ...             ...
# 20919         81570  операции с недвижимостью          низкий
# 20923         79181     расходы на автомобиль          низкий
# 20927        128240        расходы на свадьбу         средний
# 20935        219211  операции с недвижимостью         высокий
# 20942        187729               образование         средний
# 20958        204968  операции с недвижимостью         высокий
# 20969        258207               образование         высокий
# 20974        209372     расходы на автомобиль         высокий
# 20980        200883  операции с недвижимостью         высокий
# 20988        316680     расходы на автомобиль         высокий
# 20992        211722     расходы на автомобиль         высокий
# 21007        241999  операции с недвижимостью         высокий
# 21016        155849  операции с недвижимостью         средний
# 21020        237992  операции с недвижимостью         высокий
# 21022        145017  операции с недвижимостью         средний
# 21023        131833  операции с недвижимостью         средний
# 21026        350897     расходы на автомобиль         высокий
# 21041        125023     расходы на автомобиль         средний
# 21047        131854  операции с недвижимостью         средний
# 21052        115291               образование         средний
# 21053        156320  операции с недвижимостью         средний
# 21062         73535  операции с недвижимостью          низкий
# 21071         48239     расходы на автомобиль          низкий
# 21079         77417  операции с недвижимостью          низкий
# 21082         80763     расходы на автомобиль          низкий
# 21090        176369               образование         средний
# 21106        140068  операции с недвижимостью         средний
# 21110        109486               образование         средний
# 21117         89672  операции с недвижимостью          низкий
# 21118        244093     расходы на автомобиль         высокий
#
# [1739 rows x 13 columns]

# %% [markdown]
# ### Вывод

# %% [markdown]
# Выявилось, что должников без детей больше. Т.е. люди с детьми выплачивают кредиты лучше. Возможно клиенты, имеющие детей, более организованы и имеют стабильный доход, позволяющий погашать кредит в срок, нежели клиенты не имеющие детей

# %% [markdown]
# ---
# ## Комментарий от наставника
#
# Лучше вывести все таблицей. Возможно результат в относительных единицах будет на уровне статистической погрешности.
#
# -----

# %% [markdown]
# - Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
debt_and_family_status = client_data[['children', 'debt', 'family_status','family_status_id']]
print(debt_and_family_status.loc[debt_and_family_status['debt'] == 1, 'family_status'].value_counts())
print()
print('Из общего количества клинтов по наличию долгов лидирует жентатые и замужние, но это потому, что такое семейное положение')
print('наиболее популярное сриди клиентов банка, в чем убедимся посчитав количесвто значений :')
print()
print(debt_and_family_status['family_status'].value_counts())
print()
print('Рассмотрим каждую категорию по отдельности:')
print()

def family_status_ratio_counter(status): 
    str_with_debt = debt_and_family_status.loc[(debt_and_family_status['family_status'] == status) & (debt_and_family_status['debt'] == 1), 'family_status'].count()
    str_without_debt = debt_and_family_status.loc[(debt_and_family_status['family_status'] == status) & (debt_and_family_status['debt'] == 0), 'family_status'].count()
    return str_with_debt/str_without_debt

marriage_ratio = family_status_ratio_counter('женат / замужем')
print('процент должников среди жентых / замужних: {:.2%}'.format(marriage_ratio))
print()
civil_marriage_ratio = family_status_ratio_counter('гражданский брак')
print('процент должников в гражданском браке: {:.2%}'.format(civil_marriage_ratio))
print()
single_ratio = family_status_ratio_counter('Не женат / не замужем')
print('процент должников среди неженатых / незамужних: {:.2%}'.format(single_ratio))
print()
divorce_ratio = family_status_ratio_counter('в разводе')
print('процент должников среди разведенных : {:.2%}'.format(divorce_ratio))
print()
widow_ratio = family_status_ratio_counter('вдовец / вдова')
print('процент должников среди вдовцов и вдов: {:.2%}'.format(widow_ratio))
print()
# Out:
# женат / замужем          929
# гражданский брак         388
# Не женат / не замужем    274
# в разводе                 85
# вдовец / вдова            63
# Name: family_status, dtype: int64
#
# Из общего количества клинтов по наличию долгов лидирует жентатые и замужние, но это потому, что такое семейное положение
# наиболее популярное сриди клиентов банка, в чем убедимся посчитав количесвто значений :
#
# женат / замужем          12076
# гражданский брак          4124
# Не женат / не замужем     2784
# в разводе                 1193
# вдовец / вдова             943
# Name: family_status, dtype: int64
#
# Рассмотрим каждую категорию по отдельности:
#
# процент должников среди жентых / замужних: 8.33%
#
# процент должников в гражданском браке: 10.39%
#
# процент должников среди неженатых / незамужних: 10.92%
#
# процент должников среди разведенных : 7.67%
#
# процент должников среди вдовцов и вдов: 7.16%

# %%
#рассмотрим сводную таблицу
family_status_pivot_table = client_data.pivot_table(index = 'family_status', values = 'debt')
family_status_pivot_table
#значения отличаются от процентов в передыдущей ячейке, но тенденция сохраняется точно такая же
# Out:
#                            debt
# family_status
# Не женат / не замужем  0.098420
# в разводе              0.071249
# вдовец / вдова         0.066808
# гражданский брак       0.094083
# женат / замужем        0.076929

# %% [markdown]
# ### Вывод

# %% [markdown]
# После проверки добаил pivot_table для полноты предоставления результатов, но опять же в качестве значения aggfunc я использовал mean (по умолчанию), но не знаю корректна ли она в данном случае. Знаю, что есть куча numpy functions для атрибута aggfunc, но не знаю, какие лучше применять.  В ходе анализа выявилось, что больше всего должников среди неженатых и незамужних (10.80%) и людей состоящих в гражданском браке (10.31%). Меньше всего должников среди вдовцов и вдов  (7.03%) и разведенных (7.66%).

# %% [markdown]
# - Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
#расчитаем отношение клиентов с долгами к клиентам без долгов для каждой категории доходов:
def income_debt_ratio_counter(status): 
    str_with_debt = client_data.loc[(client_data['income_category'] == status) & (client_data['debt'] == 1), 'income_category'].count()
    str_without_debt = client_data.loc[(client_data['income_category'] == status) & (client_data['debt'] == 0), 'income_category'].count()
    return str_with_debt/str_without_debt
print()
low_ratio = income_debt_ratio_counter('низкий')
print('процент должников c низким доходом: {:.2%}'.format(low_ratio))
print()
medium_ratio = income_debt_ratio_counter('средний')
print('процент должников cо средним доходом: {:.2%}'.format(medium_ratio))
high_ratio = income_debt_ratio_counter('высокий')
print()
print('процент должников c высоким доходом: {:.2%}'.format(high_ratio))
print()
# Out:
# процент должников c низким доходом: 8.66%
#
# процент должников cо средним доходом: 9.80%
#
# процент должников c высоким доходом: 7.73%

# %%
client_data.head(50)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1           8437         42               высшее             0
# 1          1           4024         36              среднее             1
# 2          0           5623         33              среднее             1
# 3          3           4124         32              среднее             1
# 4          0         340266         53              среднее             1
# 5          0            926         27               высшее             0
# 6          0           2879         43               высшее             0
# 7          0            152         50              среднее             1
# 8          2           6929         35               высшее             0
# 9          0           2188         41              среднее             1
# 10         2           4171         36               высшее             0
# 11         0            792         40              среднее             1
# 12         0          66914         65              среднее             1
# 13         0           1846         54  неоконченное высшее             2
# 14         0           1844         56               высшее             0
# 15         1            972         26              среднее             1
# 16         0           1719         35              среднее             1
# 17         0           2369         33               высшее             0
# 18         0         400281         53              среднее             1
# 19         0          10038         48              среднее             1
# 20         1           1311         36              среднее             1
# 21         1            253         33              среднее             1
# 22         1           1766         24              среднее             1
# 23         0            272         21               высшее             0
# 24         1         338551         57              среднее             1
# 25         0         363548         67              среднее             1
# 26         0          66914         41              среднее             1
# 27         0            529         28               высшее             0
# 28         1            717         26               высшее             0
# 29         0          66914         63              среднее             1
# 30         1         335581         62              среднее             1
# 31         0           1682         47            начальное             3
# 32         0           4649         34              среднее             1
# 33         0           1548         48              среднее             1
# 34         0           4488         35              среднее             1
# 35         0         394021         68              среднее             1
# 36         0            176         33              среднее             1
# 37         0           6448         43               высшее             0
# 38         0            597         25               высшее             0
# 39         0            650         31               высшее             0
# 40         0           1030         30              среднее             1
# 41         0          66914         50              среднее             1
# 42         0           1257         20  неоконченное высшее             2
# 43         0           4375         43  неоконченное высшее             2
# 44         1           1362         26              среднее             1
# 45         1           1039         49              среднее             1
# 46         2           2262         37              среднее             1
# 47         1           2689         33               высшее             0
# 48         0           3341         45              среднее             1
# 49         0           1181         54              среднее             1
#
#             family_status  family_status_id gender  income_type  debt  \
# 0         женат / замужем                 0      F    сотрудник     0
# 1         женат / замужем                 0      F    сотрудник     0
# 2         женат / замужем                 0      M    сотрудник     0
# 3         женат / замужем                 0      M    сотрудник     0
# 4        гражданский брак                 1      F    пенсионер     0
# 5        гражданский брак                 1      M    компаньон     0
# 6         женат / замужем                 0      F    компаньон     0
# 7         женат / замужем                 0      M    сотрудник     0
# 8        гражданский брак                 1      F    сотрудник     0
# 9         женат / замужем                 0      M    сотрудник     0
# 10        женат / замужем                 0      M    компаньон     0
# 11        женат / замужем                 0      F    сотрудник     0
# 12       гражданский брак                 1      M    пенсионер     0
# 13        женат / замужем                 0      F    сотрудник     0
# 14       гражданский брак                 1      F    компаньон     1
# 15        женат / замужем                 0      F    сотрудник     0
# 16        женат / замужем                 0      F    сотрудник     0
# 17       гражданский брак                 1      M    сотрудник     0
# 18         вдовец / вдова                 2      F    пенсионер     0
# 19              в разводе                 3      F    сотрудник     0
# 20        женат / замужем                 0      M    сотрудник     0
# 21       гражданский брак                 1      F    сотрудник     0
# 22       гражданский брак                 1      F    сотрудник     0
# 23       гражданский брак                 1      M    сотрудник     0
# 24  Не женат / не замужем                 4      F    пенсионер     0
# 25        женат / замужем                 0      M    пенсионер     0
# 26        женат / замужем                 0      M  госслужащий     0
# 27        женат / замужем                 0      M    сотрудник     0
# 28        женат / замужем                 0      F    сотрудник     0
# 29  Не женат / не замужем                 4      F    пенсионер     0
# 30        женат / замужем                 0      F    пенсионер     0
# 31        женат / замужем                 0      F    сотрудник     0
# 32       гражданский брак                 1      F    сотрудник     1
# 33        женат / замужем                 0      F    компаньон     0
# 34        женат / замужем                 0      F    сотрудник     0
# 35       гражданский брак                 1      M    пенсионер     0
# 36  Не женат / не замужем                 4      M    сотрудник     0
# 37       гражданский брак                 1      F    компаньон     0
# 38  Не женат / не замужем                 4      M    сотрудник     1
# 39       гражданский брак                 1      F    компаньон     0
# 40  Не женат / не замужем                 4      M    компаньон     0
# 41        женат / замужем                 0      F  госслужащий     0
# 42  Не женат / не замужем                 4      F    сотрудник     0
# 43              в разводе                 3      F    компаньон     0
# 44        женат / замужем                 0      F    сотрудник     0
# 45  Не женат / не замужем                 4      F    сотрудник     0
# 46        женат / замужем                 0      F    компаньон     0
# 47       гражданский брак                 1      M  госслужащий     0
# 48        женат / замужем                 0      F    сотрудник     0
# 49        женат / замужем                 0      F    сотрудник     0
#
#     total_income                   purpose income_category
# 0         253875  операции с недвижимостью         высокий
# 1         112080     расходы на автомобиль         средний
# 2         145885  операции с недвижимостью         средний
# 3         267628               образование         высокий
# 4         158616        расходы на свадьбу         средний
# 5         255763  операции с недвижимостью         высокий
# 6         240525  операции с недвижимостью         высокий
# 7         135823               образование         средний
# 8          95856        расходы на свадьбу          низкий
# 9         144425  операции с недвижимостью         средний
# 10        113943  операции с недвижимостью         средний
# 11         77069  операции с недвижимостью          низкий
# 12        145017        расходы на свадьбу         средний
# 13        130458     расходы на автомобиль         средний
# 14        165127  операции с недвижимостью         средний
# 15        116820  операции с недвижимостью         средний
# 16        289202  операции с недвижимостью         высокий
# 17         90410  операции с недвижимостью          низкий
# 18         56823     расходы на автомобиль          низкий
# 19        242831     расходы на автомобиль         высокий
# 20        209552  операции с недвижимостью         высокий
# 21        131812     расходы на автомобиль         средний
# 22        149681     расходы на автомобиль         средний
# 23        128265        расходы на свадьбу         средний
# 24        290547  операции с недвижимостью         высокий
# 25         55112  операции с недвижимостью          низкий
# 26        145017               образование         средний
# 27        308848  операции с недвижимостью         высокий
# 28        187863  операции с недвижимостью         средний
# 29        145017  операции с недвижимостью         средний
# 30        171456  операции с недвижимостью         средний
# 31        275485  операции с недвижимостью         высокий
# 32        139057        расходы на свадьбу         средний
# 33        157245  операции с недвижимостью         средний
# 34        104660  операции с недвижимостью          низкий
# 35         77805        расходы на свадьбу          низкий
# 36        138830     расходы на автомобиль         средний
# 37        154128     расходы на автомобиль         средний
# 38        192247               образование         средний
# 39        754240               образование         высокий
# 40        142865  операции с недвижимостью         средний
# 41        145017     расходы на автомобиль         средний
# 42         82065               образование          низкий
# 43        272957     расходы на автомобиль         высокий
# 44        100780     расходы на автомобиль          низкий
# 45        106385               образование          низкий
# 46        182682     расходы на автомобиль         средний
# 47        356277        расходы на свадьбу         высокий
# 48        162065  операции с недвижимостью         средний
# 49         44591     расходы на автомобиль          низкий

# %%
#выведем среднее арифметическое задолженностей среди клиентов с ранзыми категориями доходов
#не знаю, корректо ли исрользовать среднее арифметическое в качестве показателя уровня задолженностей, но тенденция сохраняется
#как и в предыдущей ячейке - По возврату кредита в срок лидирует категория с высоким доходом, за ней идет клиенты с низким дохо-
#дом. Наиболее безответсвенные клиенты представлены средним классом, среднее арифметическое которого больше всех стремится к 1 (0,089)

income_category_pivot_table = client_data.pivot_table(index = ['income_category'], values = 'debt', aggfunc='mean')
income_category_pivot_table
# Out:
#                      debt
# income_category
# высокий          0.071732
# низкий           0.079706
# средний          0.089220

# %% [markdown]
# ### Вывод

# %% [markdown]
# Вне завсисимости от уровня дохода процент должников примерно одинаков для каждой категории. Больше всего задолженностей у клиентов со средним доходом, меньше всего - у клиентов с высоким. Для подкрепления вывода я добавил pivot_table

# %% [markdown]
# - Как разные цели кредита влияют на его возврат в срок?

# %%
client_data['purpose'].value_counts()
# Out:
# операции с недвижимостью    10578
# расходы на автомобиль        4272
# образование                  3964
# расходы на свадьбу           2306
# Name: purpose, dtype: int64

# %%
# я не удалял код для наглядности, чтобы было с чем сравнивать результаты в pivot_table

def purpose_debt_ratio_counter(status): #  функция для подсчета отношения задолжающих и незадолжающих по целям кредита
    #кол-во задолжающих по цели кредита:
    str_with_debt = client_data.loc[(client_data['purpose'] == status) & (client_data['debt'] == 1), 'income_category'].count()
    #кол-во не задолжающих по цели кредита:
    str_without_debt = client_data.loc[(client_data['purpose'] == status) & (client_data['debt'] == 0), 'income_category'].count()
    #отношение:
    return str_with_debt/str_without_debt
print()
estate_ratio = purpose_debt_ratio_counter('операции с недвижимостью')
print('процент задолженностией среди операций с недвижимостью: {:.2%}'.format(estate_ratio))
print()
car_ratio = purpose_debt_ratio_counter('расходы на автомобиль')
print('процент задолженностией среди расходов на автомобиль: {:.2%}'.format(car_ratio))
print()
education_ratio = purpose_debt_ratio_counter('образование')
print('процент задолженностией среди расходов на образование: {:.2%}'.format(education_ratio))
print()
wedding_ratio = purpose_debt_ratio_counter('расходы на свадьбу')
print('процент задолженностией среди расходов на свадьбу: {:.2%}'.format(wedding_ratio))
print()
# Out:
# процент задолженностией среди операций с недвижимостью: 7.97%
#
# процент задолженностией среди расходов на автомобиль: 10.39%
#
# процент задолженностией среди расходов на образование: 10.29%
#
# процент задолженностией среди расходов на свадьбу: 8.77%

# %%
purpose_pivot_table = client_data.pivot_table(index = 'purpose', values = 'debt', aggfunc = ['count','mean'])
purpose_pivot_table
#показатели отличаются, от показателей в коде, но тенденции сохраняются
# Out:
#                           count      mean
#                            debt      debt
# purpose
# образование                3964  0.093340
# операции с недвижимостью  10578  0.073832
# расходы на автомобиль      4272  0.094101
# расходы на свадьбу         2306  0.080659

# %% [markdown]
# ### Вывод

# %% [markdown]
# Лидирующая категория по задолженностям оказалась 'расходы на автомобиль', почти такой же показатель по задолженности и у 'образоывние'. Я предполагаю, что это связано с необдуманностью приянтия решения о кредите в связи с внезапностью такой ситуации, как, например, ремонта автомобиля. Среди клиентов, проводящих операции с недвижимостью меньше всего должников. Я думаю это связано с готовность клиентов взять обязательства на выплату долгосрочного кредита. Расходы на образование на втором месте по кол-ву задолженностей. Скорее всего это связанно с клиентами, сами оплачивающими свое образование и не имеющие стабильного дохода для выплаты кридита в срок.

# %% [markdown]
# ### Финальный анализ

# %% [markdown]
# #### Есть ли зависимость между наличием детей и возвратом кредита в срок?
#
# Количество клиентов с детьми, которые имели задолженности: 678
# Количество клиентов без детей, которые имели задолженности: 1061
# Должников без детей больше должников с детьми в 1.56 раз

# %% [markdown]
# #### Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
family_status_pivot_table
# Out:
#                            debt
# family_status
# Не женат / не замужем  0.098420
# в разводе              0.071249
# вдовец / вдова         0.066808
# гражданский брак       0.094083
# женат / замужем        0.076929

# %% [markdown]
# #### Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
income_category_pivot_table
# Out:
#                      debt
# income_category
# высокий          0.071732
# низкий           0.079706
# средний          0.089220

# %% [markdown]
# #### Как разные цели кредита влияют на его возврат в срок?

# %%
purpose_pivot_table
# Out:
#                           count      mean
#                            debt      debt
# purpose
# образование                3964  0.093340
# операции с недвижимостью  10578  0.073832
# расходы на автомобиль      4272  0.094101
# расходы на свадьбу         2306  0.080659

# %% [markdown]
# ### Шаг 4. Общий вывод

# %% [markdown]
# После подготовки данных и анализа датафрейма c информацией о клиениах крдитного банка можно сказать следущее :
# 1. Есть  зависимость между наличием детей и возвратом кредита в срок. Клиенты с детьми выплачивают кредиты в срок чаще, чем без детей
# 2. Есть зависимость между семейным положением и возвратом кредита в срок. Больше всего должников среди неженатых и незамужних  и людей состоящих в гражданском браке. Меньше всего должников среди вдовцов и вдов, разведенных .
# 3. Есть зависимость между уровнем дохода и возвратом кредита в срок . Должников со средним доходом больше должников с высоким и низким. Должников с высоким доходом немного больше, чем должников с низким
# 4. Кредиты на операции с недвижимостью и на огранизацию свадьбы выплачиваются в срок чаще, чем кредиты на расходы на автомобиль и образование.
